# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns



url ='https://github.com/HamoyeHQ/HDSC-Introduction-to-Python-for-machine-learning/files/7768140/FoodBalanceSheets_E_Africa_NOFLAG.csv'
quiz_df = pd.read_csv(url, encoding="latin-1")
quiz_df.describe()
# Out:
#           Area Code     Item Code  Element Code          Y2014          Y2015  \
# count  60943.000000  60943.000000  60943.000000   59354.000000   59395.000000
# mean     134.265576   2687.176706   3814.856456     134.196282     135.235966
# std       72.605709    146.055739   2212.007033    1567.663696    1603.403984
# min        4.000000   2501.000000    511.000000   -1796.000000   -3161.000000
# 25%       74.000000   2562.000000    684.000000       0.000000       0.000000
# 50%      136.000000   2630.000000   5142.000000       0.090000       0.080000
# 75%      195.000000   2775.000000   5511.000000       8.340000       8.460000
# max      276.000000   2961.000000   5911.000000  176405.000000  181137.000000
#
#                Y2016          Y2017          Y2018
# count   59408.000000   59437.000000   59507.000000
# mean      136.555222     140.917765     143.758381
# std      1640.007194    1671.862359    1710.782658
# min     -3225.000000   -1582.000000   -3396.000000
# ...

# %%
import numpy as np

array  = np.array([[94, 89, 63], [93, 92, 48],[92, 94, 56]])
array[:2,1:]
# Out:
# array([[89, 63],
#        [92, 48]])

# %%
# Question 3
lst = [[35, 'Portugal', 94], [33, 'Argentina', 93], [30 , 'Brazil', 92]]
col = ['Age','Nationality','Overall']

dt_dict = {'Age':[35,33,30],
          'Nationality':['Portugal','Argentina','Brazil'],
          'Overall':[94,93,92]}
df = pd.DataFrame(dt_dict, index=[1,2,3])



res_df = pd.DataFrame(lst, columns = ['Age','Nationality','Overall'], index = [1,2,3])

ok_df = pd.DataFrame(lst, columns = col, index = [i for i in range(1,4)])
print(ok_df)
# Out:
#    Age Nationality  Overall
# 1   35    Portugal       94
# 2   33   Argentina       93
# 3   30      Brazil       92

# %%
#Question 4
#quiz_df.describe(include='all')

quiz_df[['Y2017','Area']].groupby('Area').max()
# Out:
#                                  Y2017
# Area
# Algeria                       41389.00
# Angola                        29817.00
# Benin                         11175.00
# Botswana                       2341.00
# Burkina Faso                  19193.00
# Cabo Verde                     2530.00
# Cameroon                      24566.00
# Central African Republic       4596.00
# Chad                          15017.00
# Comoros                          16.65
# Congo                          5111.00
# Côte d'Ivoire                 24437.00
# Djibouti                       2664.00
# Egypt                         96443.00
# Eswatini                       5553.00
# Ethiopia                     106400.00
# Ethiopia PDR                      0.00
# Gabon                          2640.00
# Gambia                         2544.00
# Ghana                         29121.00
# Guinea                        12068.00
# Guinea-Bissau                  2233.00
# Kenya                         50221.00
# ...

# %%
quiz_df[['Y2017','Area']].groupby('Area').max()

# %%
quiz_df.ndim
# Out:
# 2

# %%
# Question 7
y = ([(2, 4), (7, 8), (1, 5, 9)])
x = y[1][1]
x
# Out:
# 8

# %%
quiz_df[['Y2017','Area']].groupby('Area')['Y2017'].min().nsmallest(100,keep='all')
# Out:
# Area
# Egypt                         -1582.0
# Mozambique                    -1200.0
# United Republic of Tanzania    -865.0
# Sudan                          -819.0
# Ethiopia                       -792.0
# Nigeria                        -694.0
# Niger                          -682.0
# Rwanda                         -631.0
# Mali                           -600.0
# Zimbabwe                       -521.0
# Madagascar                     -324.0
# Burkina Faso                   -281.0
# Angola                         -250.0
# Côte d'Ivoire                  -244.0
# Morocco                        -229.0
# Tunisia                        -186.0
# Kenya                          -186.0
# Sierra Leone                   -180.0
# Uganda                         -180.0
# Cameroon                       -147.0
# South Africa                   -144.0
# Benin                          -125.0
# Ghana                          -121.0
# Guinea                         -108.0
# ...

# %%
#Question 
quiz_df[['Item','Y2015','Y2018']].groupby('Item')['Y2015'].sum()['Wine']
# Out:
# 4251.81

# %%
quiz_df[['Item','Y2015','Y2018']].groupby('Item')['Y2018'].sum()['Wine']
# Out:
# 4039.32

# %%
# Question
quiz_df.shape
# Out:
# (60943, 12)

# %%
#Question
quiz_df.iloc[1,1]
# Out:
# 'Algeria'

# %%
#Question
quiz_df[['Y2017']].mean()
# Out:
# Y2017    140.917765
# dtype: float64

# %%
quiz_df[['Y2017']].std()
# Out:
# Y2017    1671.862359
# dtype: float64

# %%
# Question
quiz_df[['Element','Y2017']].groupby('Element').sum()
# Out:
#                                              Y2017
# Element
# Domestic supply quantity                2088198.10
# Export Quantity                          182338.80
# Fat supply quantity (g/capita/day)        10253.84
# Feed                                     223705.68
# Food                                    1258888.28
# Food supply (kcal/capita/day)            454681.00
# Food supply quantity (kg/capita/yr)       48690.04
# Import Quantity                          294559.09
# Losses                                   160614.00
# Other uses (non-food)                     91645.97
# Processing                               292836.00
# Production                              2030056.89
# Protein supply quantity (g/capita/day)    11842.45
# Residuals                                 35500.00
# Seed                                      24870.14
# Stock Variation                           54316.91
# Total Population - Both sexes           1112641.00
# ...
